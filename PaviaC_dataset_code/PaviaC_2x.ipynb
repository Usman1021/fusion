# %% [markdown]
# ## Download the dataset from the following link before using this notebook (Pavia Centre scene):

# %% [markdown]
# ##  https://www.ehu.eus/ccwintco/index.php/Hyperspectral_Remote_Sensing_Scenes

# %% [markdown]
# ## Import required libraries

# %%
from scipy.io import loadmat
import numpy as np
import tensorflow as tf
import random
import os
import matplotlib.pyplot as plt
from tensorflow.keras.layers import (
    Input, Conv2D, Conv2DTranspose, BatchNormalization,
    Activation, Add, Concatenate, UpSampling2D, DepthwiseConv2D, Lambda
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import EarlyStopping
from skimage.metrics import structural_similarity as ssim
# Out:
# 2025-05-09 16:23:38.027815: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 16:23:38.041905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746797018.057949 1501468 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746797018.063017 1501468 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-09 16:23:38.080192: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ##  Reproducibility Setup ( Set a consistent random seed for NumPy, TensorFlow, and Python's random module to ensure the same results on each run)

# %%
seed_value = 65
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)
os.environ['PYTHONHASHSEED'] = str(seed_value)

tf.config.experimental.enable_op_determinism()
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

# %% [markdown]
# ##  Load the PaviaC Dataset

# %%
data = loadmat("Pavia.mat")
if 'pavia' not in data:
    raise KeyError("'pavia' not found in the .mat file.")
hyperspectral_image = data['pavia'].astype(np.float32)

# %% [markdown]
# ##  Parameter Initialization for dataset preprocessing only

# %%
patch_size = (144, 144)
downscale_factor = 2
nodata_value = -1
group_size = 32
overlap_size = 8
validation_ratio = 0.1

# %% [markdown]
# ## Define Test Patch (Bottom-Center)

# %%
H, W, _ = hyperspectral_image.shape
patch_h, patch_w = patch_size
test_i = H - patch_h
test_j = (W - patch_w) // 2
test_coords = (test_i, test_j)

# Extract test patch
test_hr_full = hyperspectral_image[test_i:test_i + patch_h, test_j:test_j + patch_w, :]
test_lr_full = tf.image.resize(test_hr_full,
                               size=(patch_h // downscale_factor, patch_w // downscale_factor),
                               method='area').numpy()
test_hr_full = test_hr_full[np.newaxis, ...]
test_lr_full = test_lr_full[np.newaxis, ...]
# Out:
# I0000 00:00:1746797022.921723 1501468 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31141 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:62:00.0, compute capability: 7.0

# %%
# -----------------------------
# Visualize test patch
# -----------------------------
plt.figure(figsize=(6, 6))
plt.imshow(np.mean(hyperspectral_image, axis=-1), cmap='gray')
plt.gca().add_patch(plt.Rectangle((test_j, test_i), patch_w, patch_h,
                                  edgecolor='red', facecolor='none', linewidth=2))
plt.title(f"📍 Center-Bottom Test Patch at {test_coords}")
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Extract Training Patches

# %%
def extract_training_patches(data, patch_size, downscale_factor, nodata_value, test_coords):
    h, w, b = data.shape
    i_test, j_test = test_coords
    patch_h, patch_w = patch_size
    train_hr, train_lr = [], []

    for i in range(0, h - patch_h + 1, patch_h):
        for j in range(0, w - patch_w + 1, patch_w):
            if i == i_test and j == j_test:
                continue  # avoid test patch
            patch = data[i:i + patch_h, j:j + patch_w, :]
            if patch.shape[:2] != patch_size or np.any(patch == nodata_value):
                continue
            patch_lr = tf.image.resize(patch,
                                       size=(patch_h // downscale_factor, patch_w // downscale_factor),
                                       method='area').numpy()
            train_hr.append(patch)
            train_lr.append(patch_lr)
    return np.array(train_hr), np.array(train_lr)

train_hr_full, train_lr_full = extract_training_patches(
    hyperspectral_image, patch_size, downscale_factor, nodata_value, test_coords
)

# %% [markdown]
# ## Band grouping

# %%
def apply_band_grouping(patches, group_size, overlap_size):
    grouped = []
    for patch in patches:
        h, w, bands = patch.shape
        step = group_size - overlap_size
        for g in range(0, bands - group_size + 1, step):
            grouped_patch = patch[:, :, g:g + group_size]
            grouped.append(grouped_patch)
    return np.array(grouped)

X_train_hr = apply_band_grouping(train_hr_full, group_size, overlap_size)
X_train_lr = apply_band_grouping(train_lr_full, group_size, overlap_size)
X_test_hr = apply_band_grouping(test_hr_full, group_size, overlap_size)
X_test_lr = apply_band_grouping(test_lr_full, group_size, overlap_size)

# %% [markdown]
# ## Validation Split FOR train and validation

# %%
num_train = X_train_hr.shape[0]
val_size = max(1, int(validation_ratio * num_train))
indices = np.arange(num_train)
np.random.shuffle(indices)
X_train_hr = X_train_hr[indices]
X_train_lr = X_train_lr[indices]
X_validation_hr = X_train_hr[:val_size]
X_validation_lr = X_train_lr[:val_size]
X_train_hr = X_train_hr[val_size:]
X_train_lr = X_train_lr[val_size:]

# %% [markdown]
# ## Print database sizes to output the number of patches, patch height, width, and band group size for each subset.

# %%
print("Hyperspectral image shape:", hyperspectral_image.shape)
print("Train set (HR):", X_train_hr.shape)
print("Train set (LR):", X_train_lr.shape)
print("Validation set (HR):", X_validation_hr.shape)
print("Validation set (LR):", X_validation_lr.shape)
print("Test set (HR):", X_test_hr.shape)
print("Test set (LR):", X_test_lr.shape)
# Out:
# Hyperspectral image shape: (1096, 715, 102)
# Train set (HR): (76, 144, 144, 32)
# Train set (LR): (76, 72, 72, 32)
# Validation set (HR): (8, 144, 144, 32)
# Validation set (LR): (8, 72, 72, 32)
# Test set (HR): (3, 144, 144, 32)
# Test set (LR): (3, 72, 72, 32)

# %% [markdown]
# ##  Model development for Depthwise Separable Dilated Convolutional Network (https://arxiv.org/abs/2505.03431)

# %%
# -----------------------------
# Inception Block
# -----------------------------
def inception_residual_block(x, filters):
    shortcut = x

    b1 = Conv2D(filters, 1, padding='same', activation='relu')(x)

    b2 = Conv2D(filters, 1, padding='same', activation='relu')(x)
    b2 = Conv2D(filters, 3, padding='same', activation='relu')(b2)

    b3 = Conv2D(filters, 1, padding='same', activation='relu')(x)
    b3 = Conv2D(filters, 5, padding='same', activation='relu')(b3)

    b4 = Conv2D(filters, 1, padding='same', activation='relu')(x)

    merged = Concatenate()([b1, b2, b3, b4])
    merged = Conv2D(filters, 1, padding='same')(merged)
    merged = BatchNormalization()(merged)

    x = Add()([merged, shortcut])
    x = Activation('relu')(x)
    return x

# -----------------------------
# Multi-Scale Fusion Block (New)
# -----------------------------
def multi_scale_fusion_block(x, filters):
    b1 = Conv2D(filters, 1, padding='same', activation='relu')(x)
    b2 = Conv2D(filters, 3, padding='same', activation='relu')(x)
    b3 = Conv2D(filters, 5, padding='same', activation='relu')(x)
    fused = Concatenate()([b1, b2, b3])
    fused = Conv2D(filters, 1, padding='same', activation='relu')(fused)
    return fused

# -----------------------------
# Spectral-Spatial Fusion Block
# -----------------------------
def spectral_spatial_fusion_block(x, filters):
    spectral = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)
    spatial = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(spectral)
    fused = Add()([x, spatial]) if x.shape[-1] == filters else Conv2D(filters, 1, padding='same')(spatial)
    fused = Activation('relu')(fused)
    return fused

# -----------------------------
# Optimized Upsample Block
# -----------------------------
def optimized_upsample_block(x, filters, scale=2, use_residual=False, upsample_mode='transpose'):
    shortcut = x

    if upsample_mode == 'transpose':
        x = Conv2DTranspose(filters, kernel_size=4, strides=scale, padding='same', activation='relu')(x)

    elif upsample_mode == 'nearest': 
        x = UpSampling2D(size=(scale, scale), interpolation='nearest')(x)
        x = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(x)

    elif upsample_mode == 'bilinear':
        x = UpSampling2D(size=(scale, scale), interpolation='bilinear')(x)
        x = Conv2D(filters, kernel_size=3, padding='same', activation='relu')(x)

    elif upsample_mode == 'pixelshuffle':
        x = Conv2D(filters * (scale ** 2), kernel_size=3, padding='same', activation='relu')(x)
        x = Lambda(lambda t: tf.nn.depth_to_space(t, scale))(x)

    else:
        raise ValueError(f"Unknown upsample_mode: {upsample_mode}")

    x = DepthwiseConv2D(kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters, kernel_size=1, padding='same', activation='relu')(x)

    if use_residual:
        shortcut = UpSampling2D(size=(scale, scale), interpolation='nearest')(shortcut)
        if shortcut.shape[-1] != filters:
            shortcut = Conv2D(filters, 1, padding='same')(shortcut)
        x = Add()([x, shortcut])

    return x

# -----------------------------
# Model Architecture
# -----------------------------
def build_simple_sr_model(input_shape, use_residual=True, upsample_mode='transpose'):
    inputs = Input(shape=input_shape)

    x = Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=l2(1e-4))(inputs)
    x = spectral_spatial_fusion_block(x, 32)

    for _ in range(3):
        x = inception_residual_block(x, 32)

    x = multi_scale_fusion_block(x, 32)

    x = optimized_upsample_block(x, filters=312, scale=2, use_residual=use_residual, upsample_mode=upsample_mode)

    output = Conv2D(input_shape[-1], 3, padding='same', activation='linear', kernel_regularizer=l2(1e-4))(x)

    model = Model(inputs, output, name='HSI_SR_Optimized_Upsample_Model')
    return model

# -----------------------------
# Custom Combined MSE Loss
# -----------------------------
def combined_mse_l2_loss(y_true, y_pred):
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    return mse

# -----------------------------
# Compile Model
# -----------------------------
input_shape = (72, 72, 32)
model = build_simple_sr_model(input_shape=input_shape, use_residual=True, upsample_mode='bilinear')

model.compile(
    optimizer='adam',
    loss=combined_mse_l2_loss,
    metrics=[MeanSquaredError()]
)

# -----------------------------
# Parameter Count and Size
# -----------------------------
total_params = model.count_params()
size_in_bytes = total_params * 4
size_in_mb = size_in_bytes / (1024 ** 2)
print(f"📢 Model size: {size_in_mb:.2f} MB")
# Out:
# 📢 Model size: 1.83 MB

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Train the model and get the training history with early stopping
history = model.fit(
    X_train_lr, 
    X_train_hr, 
    epochs=1000, 
    batch_size=4, 
    validation_data=(X_validation_lr, X_validation_hr),
    callbacks=[early_stopping]  # Add the early stopping callback here
)

# Visualize training and validation loss over epochs
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid for better readability
plt.show()
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746797033.104011 1501555 service.cc:148] XLA service 0x7f57bc015bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746797033.104039 1501555 service.cc:156]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2025-05-09 16:23:53.260597: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1746797034.068441 1501555 cuda_dnn.cc:529] Loaded cuDNN version 90501
# I0000 00:00:1746797038.103433 1501555 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 16s 263ms/step - loss: 606782.1875 - mean_squared_error: 606782.1875 - val_loss: 144219.6250 - val_mean_squared_error: 144219.6250
# Epoch 2/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 95005.5156 - mean_squared_error: 95005.5078 - val_loss: 82907.8125 - val_mean_squared_error: 82907.8047
# Epoch 3/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 63152.8789 - mean_squared_error: 63152.8594 - val_loss: 67791.5938 - val_mean_squared_error: 67791.5781
# Epoch 4/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 51096.4258 - mean_squared_error: 51096.4180 - val_loss: 60997.9922 - val_mean_squared_error: 60997.9766
# Epoch 5/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 44972.0703 - mean_squared_error: 44972.0547 - val_loss: 52983.7266 - val_mean_squared_error: 52983.7148
# Epoch 6/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 39242.4609 - mean_squared_error: 39242.4492 - val_loss: 50229.2266 - val_mean_squared_error: 50229.2148
# Epoch 7/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 37848.2734 - mean_squared_error: 37848.2617 - val_loss: 49564.5469 - val_mean_squared_error: 49564.5352
# Epoch 8/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 36510.4023 - mean_squared_error: 36510.3906 - val_loss: 45812.2969 - val_mean_squared_error: 45812.2891
# Epoch 9/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 34690.5430 - mean_squared_error: 34690.5312 - val_loss: 47507.8555 - val_mean_squared_error: 47507.8438
# Epoch 10/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 34596.0898 - mean_squared_error: 34596.0742 - val_loss: 44072.5391 - val_mean_squared_error: 44072.5273
# Epoch 11/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 32739.1230 - mean_squared_error: 32739.1113 - val_loss: 41941.7031 - val_mean_squared_error: 41941.6875
# Epoch 12/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 30712.6113 - mean_squared_error: 30712.6035 - val_loss: 40031.2422 - val_mean_squared_error: 40031.2344
# Epoch 13/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 29680.9062 - mean_squared_error: 29680.8984 - val_loss: 38207.3750 - val_mean_squared_error: 38207.3672
# Epoch 14/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 28799.6133 - mean_squared_error: 28799.6055 - val_loss: 37422.4141 - val_mean_squared_error: 37422.4062
# Epoch 15/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 28278.9238 - mean_squared_error: 28278.9121 - val_loss: 36686.7383 - val_mean_squared_error: 36686.7266
# Epoch 16/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 27933.1836 - mean_squared_error: 27933.1719 - val_loss: 36019.6328 - val_mean_squared_error: 36019.6250
# Epoch 17/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 27897.7852 - mean_squared_error: 27897.7773 - val_loss: 41905.0938 - val_mean_squared_error: 41905.0781
# Epoch 18/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 29719.5586 - mean_squared_error: 29719.5449 - val_loss: 36935.5156 - val_mean_squared_error: 36935.5000
# Epoch 19/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 27380.0547 - mean_squared_error: 27380.0430 - val_loss: 34203.9766 - val_mean_squared_error: 34203.9688
# Epoch 20/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 25894.1973 - mean_squared_error: 25894.1875 - val_loss: 33776.9219 - val_mean_squared_error: 33776.9062
# Epoch 21/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 25558.4746 - mean_squared_error: 25558.4629 - val_loss: 33307.4609 - val_mean_squared_error: 33307.4531
# Epoch 22/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 25308.3555 - mean_squared_error: 25308.3457 - val_loss: 33595.3672 - val_mean_squared_error: 33595.3555
# Epoch 23/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 26130.0234 - mean_squared_error: 26130.0156 - val_loss: 36092.7891 - val_mean_squared_error: 36092.7734
# Epoch 24/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 27770.3027 - mean_squared_error: 27770.2910 - val_loss: 35757.0859 - val_mean_squared_error: 35757.0703
# Epoch 25/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 27633.9043 - mean_squared_error: 27633.8965 - val_loss: 35162.3828 - val_mean_squared_error: 35162.3711
# Epoch 26/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 26021.8223 - mean_squared_error: 26021.8105 - val_loss: 33874.7812 - val_mean_squared_error: 33874.7734
# Epoch 27/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 25250.3086 - mean_squared_error: 25250.2949 - val_loss: 34201.1289 - val_mean_squared_error: 34201.1172
# Epoch 28/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 25124.1660 - mean_squared_error: 25124.1543 - val_loss: 33305.6016 - val_mean_squared_error: 33305.5898
# Epoch 29/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 24508.3145 - mean_squared_error: 24508.3066 - val_loss: 31351.2188 - val_mean_squared_error: 31351.2070
# Epoch 30/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 23534.3281 - mean_squared_error: 23534.3203 - val_loss: 30755.9023 - val_mean_squared_error: 30755.8945
# Epoch 31/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 23127.9609 - mean_squared_error: 23127.9492 - val_loss: 30286.8555 - val_mean_squared_error: 30286.8438
# Epoch 32/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 22854.6660 - mean_squared_error: 22854.6562 - val_loss: 30093.4258 - val_mean_squared_error: 30093.4160
# Epoch 33/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 22776.4395 - mean_squared_error: 22776.4316 - val_loss: 30601.8320 - val_mean_squared_error: 30601.8203
# Epoch 34/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 23033.1191 - mean_squared_error: 23033.1113 - val_loss: 29477.0781 - val_mean_squared_error: 29477.0664
# Epoch 35/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 22269.3750 - mean_squared_error: 22269.3652 - val_loss: 29773.2520 - val_mean_squared_error: 29773.2422
# Epoch 36/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 22767.6133 - mean_squared_error: 22767.6035 - val_loss: 30135.8711 - val_mean_squared_error: 30135.8613
# Epoch 37/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 23141.1738 - mean_squared_error: 23141.1660 - val_loss: 37434.4648 - val_mean_squared_error: 37434.4531
# Epoch 38/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 25026.5371 - mean_squared_error: 25026.5254 - val_loss: 29025.9922 - val_mean_squared_error: 29025.9824
# Epoch 39/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21837.4844 - mean_squared_error: 21837.4746 - val_loss: 29093.3242 - val_mean_squared_error: 29093.3125
# Epoch 40/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 21675.0410 - mean_squared_error: 21675.0332 - val_loss: 28892.4258 - val_mean_squared_error: 28892.4141
# Epoch 41/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 21449.4844 - mean_squared_error: 21449.4746 - val_loss: 28564.6172 - val_mean_squared_error: 28564.6055
# Epoch 42/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21355.5234 - mean_squared_error: 21355.5137 - val_loss: 29164.3848 - val_mean_squared_error: 29164.3770
# Epoch 43/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 21643.4297 - mean_squared_error: 21643.4219 - val_loss: 28012.6094 - val_mean_squared_error: 28012.5977
# Epoch 44/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 21068.7051 - mean_squared_error: 21068.6973 - val_loss: 27906.3867 - val_mean_squared_error: 27906.3789
# Epoch 45/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21284.8828 - mean_squared_error: 21284.8730 - val_loss: 30064.6406 - val_mean_squared_error: 30064.6328
# Epoch 46/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 22262.5195 - mean_squared_error: 22262.5078 - val_loss: 27822.8008 - val_mean_squared_error: 27822.7910
# Epoch 47/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 21043.8633 - mean_squared_error: 21043.8535 - val_loss: 27585.7871 - val_mean_squared_error: 27585.7773
# Epoch 48/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20836.6504 - mean_squared_error: 20836.6426 - val_loss: 28424.5312 - val_mean_squared_error: 28424.5195
# Epoch 49/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21186.8301 - mean_squared_error: 21186.8203 - val_loss: 27744.9453 - val_mean_squared_error: 27744.9355
# Epoch 50/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20925.7949 - mean_squared_error: 20925.7832 - val_loss: 29077.4824 - val_mean_squared_error: 29077.4727
# Epoch 51/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21876.3438 - mean_squared_error: 21876.3340 - val_loss: 28587.8320 - val_mean_squared_error: 28587.8242
# Epoch 52/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21310.0723 - mean_squared_error: 21310.0625 - val_loss: 27614.5430 - val_mean_squared_error: 27614.5312
# Epoch 53/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 20370.6191 - mean_squared_error: 20370.6113 - val_loss: 26783.9277 - val_mean_squared_error: 26783.9180
# Epoch 54/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20193.0117 - mean_squared_error: 20193.0020 - val_loss: 28529.8418 - val_mean_squared_error: 28529.8320
# Epoch 55/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20937.6035 - mean_squared_error: 20937.5938 - val_loss: 26986.9414 - val_mean_squared_error: 26986.9336
# Epoch 56/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20314.9180 - mean_squared_error: 20314.9082 - val_loss: 27687.5977 - val_mean_squared_error: 27687.5879
# Epoch 57/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 21038.6973 - mean_squared_error: 21038.6895 - val_loss: 33189.6875 - val_mean_squared_error: 33189.6797
# Epoch 58/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 22969.8184 - mean_squared_error: 22969.8086 - val_loss: 27888.8984 - val_mean_squared_error: 27888.8828
# Epoch 59/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 20351.8184 - mean_squared_error: 20351.8086 - val_loss: 26229.1016 - val_mean_squared_error: 26229.0938
# Epoch 60/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 19531.2988 - mean_squared_error: 19531.2871 - val_loss: 26043.1055 - val_mean_squared_error: 26043.0977
# Epoch 61/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19254.8828 - mean_squared_error: 19254.8730 - val_loss: 26336.1523 - val_mean_squared_error: 26336.1426
# Epoch 62/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 19342.8086 - mean_squared_error: 19342.7988 - val_loss: 26026.6523 - val_mean_squared_error: 26026.6426
# Epoch 63/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 19156.5293 - mean_squared_error: 19156.5176 - val_loss: 25947.3438 - val_mean_squared_error: 25947.3320
# Epoch 64/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19029.8848 - mean_squared_error: 19029.8770 - val_loss: 26706.0410 - val_mean_squared_error: 26706.0332
# Epoch 65/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19388.3457 - mean_squared_error: 19388.3359 - val_loss: 26111.0938 - val_mean_squared_error: 26111.0820
# Epoch 66/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19213.6914 - mean_squared_error: 19213.6816 - val_loss: 26748.5352 - val_mean_squared_error: 26748.5234
# Epoch 67/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19960.4980 - mean_squared_error: 19960.4883 - val_loss: 32669.3281 - val_mean_squared_error: 32669.3164
# Epoch 68/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 22033.2402 - mean_squared_error: 22033.2324 - val_loss: 28525.7227 - val_mean_squared_error: 28525.7129
# Epoch 69/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20197.8613 - mean_squared_error: 20197.8516 - val_loss: 26903.2344 - val_mean_squared_error: 26903.2266
# Epoch 70/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 19180.7676 - mean_squared_error: 19180.7559 - val_loss: 25653.2207 - val_mean_squared_error: 25653.2109
# Epoch 71/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18613.2715 - mean_squared_error: 18613.2617 - val_loss: 25932.4336 - val_mean_squared_error: 25932.4258
# Epoch 72/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 18678.5137 - mean_squared_error: 18678.5039 - val_loss: 25352.9258 - val_mean_squared_error: 25352.9160
# Epoch 73/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 18392.5977 - mean_squared_error: 18392.5879 - val_loss: 25294.9668 - val_mean_squared_error: 25294.9590
# Epoch 74/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18466.9609 - mean_squared_error: 18466.9531 - val_loss: 27101.2070 - val_mean_squared_error: 27101.1934
# Epoch 75/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19174.6797 - mean_squared_error: 19174.6680 - val_loss: 25335.4180 - val_mean_squared_error: 25335.4062
# Epoch 76/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18494.8535 - mean_squared_error: 18494.8457 - val_loss: 26155.9590 - val_mean_squared_error: 26155.9492
# Epoch 77/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19168.6602 - mean_squared_error: 19168.6504 - val_loss: 31148.7812 - val_mean_squared_error: 31148.7695
# Epoch 78/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20556.3926 - mean_squared_error: 20556.3828 - val_loss: 25708.0781 - val_mean_squared_error: 25708.0664
# Epoch 79/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18735.5859 - mean_squared_error: 18735.5762 - val_loss: 25325.1523 - val_mean_squared_error: 25325.1406
# Epoch 80/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18086.6680 - mean_squared_error: 18086.6602 - val_loss: 25413.7305 - val_mean_squared_error: 25413.7148
# Epoch 81/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 18042.4316 - mean_squared_error: 18042.4219 - val_loss: 25136.8867 - val_mean_squared_error: 25136.8750
# Epoch 82/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 17818.1113 - mean_squared_error: 17818.0996 - val_loss: 24901.4824 - val_mean_squared_error: 24901.4707
# Epoch 83/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17646.1836 - mean_squared_error: 17646.1738 - val_loss: 24936.4375 - val_mean_squared_error: 24936.4277
# Epoch 84/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 17668.7227 - mean_squared_error: 17668.7129 - val_loss: 24742.9180 - val_mean_squared_error: 24742.9102
# Epoch 85/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 17470.8945 - mean_squared_error: 17470.8828 - val_loss: 24706.1250 - val_mean_squared_error: 24706.1152
# Epoch 86/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17430.6934 - mean_squared_error: 17430.6836 - val_loss: 25330.1484 - val_mean_squared_error: 25330.1367
# Epoch 87/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18094.3438 - mean_squared_error: 18094.3359 - val_loss: 25651.9121 - val_mean_squared_error: 25651.9023
# Epoch 88/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18326.5742 - mean_squared_error: 18326.5664 - val_loss: 27546.8555 - val_mean_squared_error: 27546.8438
# Epoch 89/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19716.2910 - mean_squared_error: 19716.2812 - val_loss: 25552.1602 - val_mean_squared_error: 25552.1523
# Epoch 90/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18683.2207 - mean_squared_error: 18683.2090 - val_loss: 26541.7773 - val_mean_squared_error: 26541.7656
# Epoch 91/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19171.4961 - mean_squared_error: 19171.4883 - val_loss: 28767.6348 - val_mean_squared_error: 28767.6250
# Epoch 92/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20261.7949 - mean_squared_error: 20261.7852 - val_loss: 25240.9180 - val_mean_squared_error: 25240.9062
# Epoch 93/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 17699.4863 - mean_squared_error: 17699.4766 - val_loss: 24484.6836 - val_mean_squared_error: 24484.6719
# Epoch 94/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17046.8867 - mean_squared_error: 17046.8770 - val_loss: 24496.2148 - val_mean_squared_error: 24496.2051
# Epoch 95/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 16798.7539 - mean_squared_error: 16798.7441 - val_loss: 24153.8945 - val_mean_squared_error: 24153.8828
# Epoch 96/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 16573.3047 - mean_squared_error: 16573.2949 - val_loss: 24090.1152 - val_mean_squared_error: 24090.1055
# Epoch 97/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16449.2441 - mean_squared_error: 16449.2344 - val_loss: 24256.6992 - val_mean_squared_error: 24256.6895
# Epoch 98/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 16473.2969 - mean_squared_error: 16473.2871 - val_loss: 24040.6680 - val_mean_squared_error: 24040.6582
# Epoch 99/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16308.8975 - mean_squared_error: 16308.8877 - val_loss: 24056.1523 - val_mean_squared_error: 24056.1445
# Epoch 100/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16229.0732 - mean_squared_error: 16229.0635 - val_loss: 24397.2109 - val_mean_squared_error: 24397.1992
# Epoch 101/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16534.1289 - mean_squared_error: 16534.1172 - val_loss: 24875.6758 - val_mean_squared_error: 24875.6680
# Epoch 102/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16789.5898 - mean_squared_error: 16789.5781 - val_loss: 24335.0898 - val_mean_squared_error: 24335.0781
# Epoch 103/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16698.3301 - mean_squared_error: 16698.3203 - val_loss: 25712.1113 - val_mean_squared_error: 25712.1016
# Epoch 104/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18150.4688 - mean_squared_error: 18150.4590 - val_loss: 27256.2734 - val_mean_squared_error: 27256.2617
# Epoch 105/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18670.3691 - mean_squared_error: 18670.3594 - val_loss: 25223.3379 - val_mean_squared_error: 25223.3281
# Epoch 106/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17573.2871 - mean_squared_error: 17573.2793 - val_loss: 24900.8711 - val_mean_squared_error: 24900.8613
# Epoch 107/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17747.7715 - mean_squared_error: 17747.7617 - val_loss: 29305.0039 - val_mean_squared_error: 29304.9941
# Epoch 108/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 19717.8691 - mean_squared_error: 19717.8594 - val_loss: 25652.5977 - val_mean_squared_error: 25652.5859
# Epoch 109/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17948.1797 - mean_squared_error: 17948.1719 - val_loss: 25603.3359 - val_mean_squared_error: 25603.3281
# Epoch 110/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16856.7676 - mean_squared_error: 16856.7578 - val_loss: 24168.2305 - val_mean_squared_error: 24168.2227
# Epoch 111/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 16147.0195 - mean_squared_error: 16147.0098 - val_loss: 23875.3496 - val_mean_squared_error: 23875.3398
# Epoch 112/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 15914.4590 - mean_squared_error: 15914.4492 - val_loss: 23533.2500 - val_mean_squared_error: 23533.2383
# Epoch 113/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15707.2910 - mean_squared_error: 15707.2822 - val_loss: 23576.7871 - val_mean_squared_error: 23576.7754
# Epoch 114/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15565.3105 - mean_squared_error: 15565.3008 - val_loss: 23673.1953 - val_mean_squared_error: 23673.1836
# Epoch 115/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 15620.0420 - mean_squared_error: 15620.0332 - val_loss: 23308.3438 - val_mean_squared_error: 23308.3320
# Epoch 116/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15537.2725 - mean_squared_error: 15537.2637 - val_loss: 23438.2109 - val_mean_squared_error: 23438.1992
# Epoch 117/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15502.0186 - mean_squared_error: 15502.0098 - val_loss: 24042.8711 - val_mean_squared_error: 24042.8594
# Epoch 118/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15920.8594 - mean_squared_error: 15920.8506 - val_loss: 24408.6992 - val_mean_squared_error: 24408.6895
# Epoch 119/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15913.7725 - mean_squared_error: 15913.7607 - val_loss: 24123.3086 - val_mean_squared_error: 24123.2988
# Epoch 120/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15983.0146 - mean_squared_error: 15983.0068 - val_loss: 23775.1484 - val_mean_squared_error: 23775.1387
# Epoch 121/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15906.1904 - mean_squared_error: 15906.1816 - val_loss: 28790.0820 - val_mean_squared_error: 28790.0762
# Epoch 122/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 18069.9199 - mean_squared_error: 18069.9102 - val_loss: 26709.5352 - val_mean_squared_error: 26709.5234
# Epoch 123/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17511.1426 - mean_squared_error: 17511.1328 - val_loss: 24790.4688 - val_mean_squared_error: 24790.4570
# Epoch 124/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15886.2705 - mean_squared_error: 15886.2598 - val_loss: 23759.5391 - val_mean_squared_error: 23759.5293
# Epoch 125/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15360.3584 - mean_squared_error: 15360.3477 - val_loss: 23569.4355 - val_mean_squared_error: 23569.4258
# Epoch 126/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15223.8770 - mean_squared_error: 15223.8672 - val_loss: 24771.2285 - val_mean_squared_error: 24771.2188
# Epoch 127/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15451.7637 - mean_squared_error: 15451.7539 - val_loss: 23708.4570 - val_mean_squared_error: 23708.4453
# Epoch 128/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15021.2539 - mean_squared_error: 15021.2441 - val_loss: 23444.3750 - val_mean_squared_error: 23444.3672
# Epoch 129/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15228.6602 - mean_squared_error: 15228.6504 - val_loss: 26071.9961 - val_mean_squared_error: 26071.9844
# Epoch 130/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16926.4023 - mean_squared_error: 16926.3945 - val_loss: 25987.7461 - val_mean_squared_error: 25987.7344
# Epoch 131/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17064.3730 - mean_squared_error: 17064.3613 - val_loss: 24262.3438 - val_mean_squared_error: 24262.3320
# Epoch 132/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16098.7471 - mean_squared_error: 16098.7393 - val_loss: 25412.3652 - val_mean_squared_error: 25412.3574
# Epoch 133/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16044.9248 - mean_squared_error: 16044.9150 - val_loss: 23737.5586 - val_mean_squared_error: 23737.5469
# Epoch 134/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 15007.8154 - mean_squared_error: 15007.8047 - val_loss: 23286.8516 - val_mean_squared_error: 23286.8418
# Epoch 135/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 15014.5488 - mean_squared_error: 15014.5391 - val_loss: 23188.4629 - val_mean_squared_error: 23188.4531
# Epoch 136/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14726.8027 - mean_squared_error: 14726.7930 - val_loss: 23790.8984 - val_mean_squared_error: 23790.8906
# Epoch 137/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14741.8066 - mean_squared_error: 14741.7969 - val_loss: 23210.7051 - val_mean_squared_error: 23210.6953
# Epoch 138/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14539.0986 - mean_squared_error: 14539.0889 - val_loss: 24018.1797 - val_mean_squared_error: 24018.1719
# Epoch 139/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14751.9961 - mean_squared_error: 14751.9863 - val_loss: 23291.3008 - val_mean_squared_error: 23291.2910
# Epoch 140/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14481.1914 - mean_squared_error: 14481.1816 - val_loss: 23204.5859 - val_mean_squared_error: 23204.5781
# Epoch 141/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14397.4492 - mean_squared_error: 14397.4395 - val_loss: 24050.2949 - val_mean_squared_error: 24050.2852
# Epoch 142/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15008.8184 - mean_squared_error: 15008.8076 - val_loss: 23538.2285 - val_mean_squared_error: 23538.2188
# Epoch 143/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14712.5645 - mean_squared_error: 14712.5547 - val_loss: 23519.5195 - val_mean_squared_error: 23519.5078
# Epoch 144/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14453.7285 - mean_squared_error: 14453.7178 - val_loss: 23584.7637 - val_mean_squared_error: 23584.7539
# Epoch 145/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 14461.7783 - mean_squared_error: 14461.7686 - val_loss: 23000.1719 - val_mean_squared_error: 23000.1641
# Epoch 146/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14224.0234 - mean_squared_error: 14224.0146 - val_loss: 23207.7832 - val_mean_squared_error: 23207.7734
# Epoch 147/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14695.3018 - mean_squared_error: 14695.2910 - val_loss: 25183.7891 - val_mean_squared_error: 25183.7773
# Epoch 148/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15811.2441 - mean_squared_error: 15811.2354 - val_loss: 24200.6406 - val_mean_squared_error: 24200.6328
# Epoch 149/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15164.6436 - mean_squared_error: 15164.6338 - val_loss: 31230.8633 - val_mean_squared_error: 31230.8555
# Epoch 150/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 20017.9668 - mean_squared_error: 20017.9551 - val_loss: 27713.3750 - val_mean_squared_error: 27713.3633
# Epoch 151/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16551.5859 - mean_squared_error: 16551.5781 - val_loss: 24419.5703 - val_mean_squared_error: 24419.5605
# Epoch 152/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14701.9453 - mean_squared_error: 14701.9365 - val_loss: 23228.5312 - val_mean_squared_error: 23228.5195
# Epoch 153/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14153.2549 - mean_squared_error: 14153.2451 - val_loss: 23267.4023 - val_mean_squared_error: 23267.3926
# Epoch 154/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13888.8955 - mean_squared_error: 13888.8867 - val_loss: 23351.0566 - val_mean_squared_error: 23351.0469
# Epoch 155/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13702.2500 - mean_squared_error: 13702.2383 - val_loss: 23426.0391 - val_mean_squared_error: 23426.0273
# Epoch 156/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13680.7676 - mean_squared_error: 13680.7578 - val_loss: 23238.8008 - val_mean_squared_error: 23238.7910
# Epoch 157/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13669.9688 - mean_squared_error: 13669.9600 - val_loss: 23397.6289 - val_mean_squared_error: 23397.6211
# Epoch 158/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13754.6523 - mean_squared_error: 13754.6436 - val_loss: 23656.3750 - val_mean_squared_error: 23656.3672
# Epoch 159/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 13939.1475 - mean_squared_error: 13939.1377 - val_loss: 22866.3555 - val_mean_squared_error: 22866.3438
# Epoch 160/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13894.2852 - mean_squared_error: 13894.2754 - val_loss: 23026.5391 - val_mean_squared_error: 23026.5312
# Epoch 161/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14198.8809 - mean_squared_error: 14198.8721 - val_loss: 28845.6797 - val_mean_squared_error: 28845.6699
# Epoch 162/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 17496.0156 - mean_squared_error: 17496.0078 - val_loss: 25982.6055 - val_mean_squared_error: 25982.5957
# Epoch 163/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 16994.1172 - mean_squared_error: 16994.1074 - val_loss: 23348.3809 - val_mean_squared_error: 23348.3711
# Epoch 164/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14806.9277 - mean_squared_error: 14806.9189 - val_loss: 24121.8789 - val_mean_squared_error: 24121.8691
# Epoch 165/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 14866.5566 - mean_squared_error: 14866.5469 - val_loss: 22694.3398 - val_mean_squared_error: 22694.3320
# Epoch 166/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13539.7529 - mean_squared_error: 13539.7432 - val_loss: 23112.6504 - val_mean_squared_error: 23112.6406
# Epoch 167/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13514.0547 - mean_squared_error: 13514.0459 - val_loss: 23418.0352 - val_mean_squared_error: 23418.0273
# Epoch 168/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13471.8213 - mean_squared_error: 13471.8115 - val_loss: 23212.5840 - val_mean_squared_error: 23212.5742
# Epoch 169/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13482.5928 - mean_squared_error: 13482.5840 - val_loss: 23868.4512 - val_mean_squared_error: 23868.4395
# Epoch 170/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13725.6221 - mean_squared_error: 13725.6123 - val_loss: 22941.6289 - val_mean_squared_error: 22941.6172
# Epoch 171/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13564.2090 - mean_squared_error: 13564.1973 - val_loss: 23290.3145 - val_mean_squared_error: 23290.3047
# Epoch 172/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13677.0527 - mean_squared_error: 13677.0430 - val_loss: 22762.1797 - val_mean_squared_error: 22762.1680
# Epoch 173/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13324.3994 - mean_squared_error: 13324.3887 - val_loss: 23048.5488 - val_mean_squared_error: 23048.5391
# Epoch 174/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13565.3867 - mean_squared_error: 13565.3760 - val_loss: 24894.3867 - val_mean_squared_error: 24894.3750
# Epoch 175/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14361.2207 - mean_squared_error: 14361.2090 - val_loss: 23910.5625 - val_mean_squared_error: 23910.5547
# Epoch 176/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13986.1855 - mean_squared_error: 13986.1777 - val_loss: 23668.5156 - val_mean_squared_error: 23668.5059
# Epoch 177/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13992.3174 - mean_squared_error: 13992.3066 - val_loss: 26560.9922 - val_mean_squared_error: 26560.9805
# Epoch 178/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15000.5205 - mean_squared_error: 15000.5098 - val_loss: 23368.3379 - val_mean_squared_error: 23368.3262
# Epoch 179/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13876.4385 - mean_squared_error: 13876.4277 - val_loss: 23160.8242 - val_mean_squared_error: 23160.8125
# Epoch 180/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13790.2217 - mean_squared_error: 13790.2109 - val_loss: 26205.9707 - val_mean_squared_error: 26205.9590
# Epoch 181/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14522.5498 - mean_squared_error: 14522.5400 - val_loss: 22877.8984 - val_mean_squared_error: 22877.8867
# Epoch 182/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13328.8320 - mean_squared_error: 13328.8223 - val_loss: 23580.6953 - val_mean_squared_error: 23580.6836
# Epoch 183/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13250.9961 - mean_squared_error: 13250.9863 - val_loss: 23193.6895 - val_mean_squared_error: 23193.6777
# Epoch 184/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13032.3740 - mean_squared_error: 13032.3643 - val_loss: 23655.6875 - val_mean_squared_error: 23655.6758
# Epoch 185/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 13318.6406 - mean_squared_error: 13318.6318 - val_loss: 22529.3242 - val_mean_squared_error: 22529.3125
# Epoch 186/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13232.8428 - mean_squared_error: 13232.8320 - val_loss: 23243.3633 - val_mean_squared_error: 23243.3516
# Epoch 187/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13059.1309 - mean_squared_error: 13059.1211 - val_loss: 23097.0762 - val_mean_squared_error: 23097.0664
# Epoch 188/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 12855.2500 - mean_squared_error: 12855.2393 - val_loss: 22497.8789 - val_mean_squared_error: 22497.8672
# Epoch 189/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 12716.0830 - mean_squared_error: 12716.0742 - val_loss: 22549.3633 - val_mean_squared_error: 22549.3516
# Epoch 190/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12648.9277 - mean_squared_error: 12648.9189 - val_loss: 23066.9941 - val_mean_squared_error: 23066.9824
# Epoch 191/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12572.1729 - mean_squared_error: 12572.1631 - val_loss: 22546.8906 - val_mean_squared_error: 22546.8789
# Epoch 192/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 12374.3350 - mean_squared_error: 12374.3252 - val_loss: 22427.3008 - val_mean_squared_error: 22427.2871
# Epoch 193/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - loss: 12309.5049 - mean_squared_error: 12309.4951 - val_loss: 22333.6445 - val_mean_squared_error: 22333.6328
# Epoch 194/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12296.3105 - mean_squared_error: 12296.2988 - val_loss: 22547.2383 - val_mean_squared_error: 22547.2266
# Epoch 195/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12455.2676 - mean_squared_error: 12455.2568 - val_loss: 23003.6602 - val_mean_squared_error: 23003.6484
# Epoch 196/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12750.9824 - mean_squared_error: 12750.9727 - val_loss: 24250.9512 - val_mean_squared_error: 24250.9414
# Epoch 197/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13897.6182 - mean_squared_error: 13897.6074 - val_loss: 23217.4531 - val_mean_squared_error: 23217.4414
# Epoch 198/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13260.5771 - mean_squared_error: 13260.5674 - val_loss: 26452.0781 - val_mean_squared_error: 26452.0664
# Epoch 199/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 15537.3613 - mean_squared_error: 15537.3506 - val_loss: 25521.7266 - val_mean_squared_error: 25521.7148
# Epoch 200/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13968.2246 - mean_squared_error: 13968.2139 - val_loss: 23816.4004 - val_mean_squared_error: 23816.3906
# Epoch 201/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13385.9258 - mean_squared_error: 13385.9150 - val_loss: 28493.4414 - val_mean_squared_error: 28493.4297
# Epoch 202/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14845.4512 - mean_squared_error: 14845.4395 - val_loss: 24719.5879 - val_mean_squared_error: 24719.5781
# Epoch 203/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13416.3662 - mean_squared_error: 13416.3574 - val_loss: 25413.0586 - val_mean_squared_error: 25413.0469
# Epoch 204/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13296.9492 - mean_squared_error: 13296.9395 - val_loss: 23164.2012 - val_mean_squared_error: 23164.1895
# Epoch 205/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12779.3096 - mean_squared_error: 12779.2998 - val_loss: 23200.4160 - val_mean_squared_error: 23200.4043
# Epoch 206/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12749.7559 - mean_squared_error: 12749.7451 - val_loss: 24223.5312 - val_mean_squared_error: 24223.5195
# Epoch 207/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13162.9150 - mean_squared_error: 13162.9043 - val_loss: 23765.2539 - val_mean_squared_error: 23765.2441
# Epoch 208/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12830.3486 - mean_squared_error: 12830.3398 - val_loss: 23745.8164 - val_mean_squared_error: 23745.8027
# Epoch 209/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12654.1748 - mean_squared_error: 12654.1650 - val_loss: 22987.3008 - val_mean_squared_error: 22987.2891
# Epoch 210/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12827.1172 - mean_squared_error: 12827.1064 - val_loss: 22967.9238 - val_mean_squared_error: 22967.9102
# Epoch 211/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12680.8848 - mean_squared_error: 12680.8770 - val_loss: 23024.2441 - val_mean_squared_error: 23024.2344
# Epoch 212/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12563.6191 - mean_squared_error: 12563.6094 - val_loss: 23648.0391 - val_mean_squared_error: 23648.0273
# Epoch 213/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12505.0801 - mean_squared_error: 12505.0703 - val_loss: 22666.9922 - val_mean_squared_error: 22666.9805
# Epoch 214/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12138.5977 - mean_squared_error: 12138.5879 - val_loss: 23000.7070 - val_mean_squared_error: 23000.6953
# Epoch 215/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12491.4629 - mean_squared_error: 12491.4531 - val_loss: 24814.6582 - val_mean_squared_error: 24814.6445
# Epoch 216/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13226.9629 - mean_squared_error: 13226.9551 - val_loss: 23752.1191 - val_mean_squared_error: 23752.1055
# Epoch 217/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12372.2461 - mean_squared_error: 12372.2363 - val_loss: 26250.6523 - val_mean_squared_error: 26250.6367
# Epoch 218/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13693.2256 - mean_squared_error: 13693.2158 - val_loss: 24263.5117 - val_mean_squared_error: 24263.5000
# Epoch 219/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12948.5000 - mean_squared_error: 12948.4902 - val_loss: 24482.8477 - val_mean_squared_error: 24482.8359
# Epoch 220/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 13365.9727 - mean_squared_error: 13365.9629 - val_loss: 30081.4492 - val_mean_squared_error: 30081.4375
# Epoch 221/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 14919.3135 - mean_squared_error: 14919.3027 - val_loss: 23624.6328 - val_mean_squared_error: 23624.6211
# Epoch 222/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12528.8672 - mean_squared_error: 12528.8584 - val_loss: 23155.6641 - val_mean_squared_error: 23155.6523
# Epoch 223/1000
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - loss: 12084.2871 - mean_squared_error: 12084.2773 - val_loss: 22980.4102 - val_mean_squared_error: 22980.3984

# %% [markdown]
# ##  Save trained model

# %%
model.save('PaviaC_2x_saved_model.keras')

# %% [markdown]
# ## Report the six types of results in terms of PSNR, SSIM, SAM, Correlation Coefficient, ERGAS, and RMSE.

# %%
def psnr(y_true, y_pred, max_pixel=None):
    """
    Compute PSNR for each spectral band separately and return the average.
    
    Args:
        y_true: Ground truth image, shape (H, W, B)
        y_pred: Super-resolved image, shape (H, W, B)
        max_pixel: Maximum pixel value (None = use actual max from y_true)
    
    Returns:
        Average PSNR across all bands
    """
    if max_pixel is None:
        max_pixel = np.max(y_true)  # Auto-detect max value if not provided

    B = y_true.shape[-1]  # Number of spectral bands
    psnr_values = []
    
    for i in range(B):  # Loop over bands
        mse = np.mean((y_true[..., i] - y_pred[..., i]) ** 2)
        if mse == 0:
            psnr_values.append(float('inf'))  # Perfect reconstruction
        else:
            psnr = 20 * np.log10(max_pixel / np.sqrt(mse))
            psnr_values.append(psnr)
    
    return np.mean(psnr_values)  # Average across bands

# Function to calculate SSIM with channel_axis
def ssim_value(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError(f"Shape mismatch: y_true shape {y_true.shape} vs y_pred shape {y_pred.shape}")
    
    data_range = y_true.max() - y_true.min()  # Calculate data range from y_true
    ssim_val = ssim(y_true, y_pred, data_range=data_range, channel_axis=-1)
    return ssim_val

# Function to calculate Correlation Coefficient
def correlation_coefficient(y_true, y_pred):
    y_true_flat = y_true.flatten()
    y_pred_flat = y_pred.flatten()
    corr_matrix = np.corrcoef(y_true_flat, y_pred_flat)
    corr_value = corr_matrix[0, 1]
    return corr_value

# Function to calculate Spectral Angle Mapper (SAM) in degrees
def sam(y_true, y_pred):
    y_true_reshaped = y_true.reshape(-1, y_true.shape[-1])
    y_pred_reshaped = y_pred.reshape(-1, y_pred.shape[-1])
    
    non_zero_mask = (np.linalg.norm(y_true_reshaped, axis=1) > 1e-10) & (np.linalg.norm(y_pred_reshaped, axis=1) > 1e-10)
    dot_product = np.sum(y_true_reshaped[non_zero_mask] * y_pred_reshaped[non_zero_mask], axis=1)
    norm_true = np.linalg.norm(y_true_reshaped[non_zero_mask], axis=1)
    norm_pred = np.linalg.norm(y_pred_reshaped[non_zero_mask], axis=1)
    
    with np.errstate(divide='ignore', invalid='ignore'):
        angles = np.arccos(np.clip(dot_product / (norm_true * norm_pred), -1.0, 1.0))
    
    if angles.size > 0:
        sam_value_degrees = np.mean(angles) * (180 / np.pi)
    else:
        sam_value_degrees = 0
    
    return sam_value_degrees

# Function to normalize the images
def normalize(image):
    min_val = np.min(image)
    max_val = np.max(image)
    return (image - min_val) / (max_val - min_val)  # Normalize to [0, 1]

# Function to calculate Root Mean Squared Error (RMSE) for hyperspectral images (normalized)
def rmse_bandwise(y_true, y_pred):
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch between true and predicted images.")
    
    bands = y_true.shape[-1]
    rmse_per_band = []

    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        
        mse_band = np.mean((band_true - band_pred) ** 2)
        rmse_band_value = np.sqrt(mse_band)
        rmse_per_band.append(rmse_band_value)

    # Normalize RMSE by the maximum value in y_true across all bands
    max_value = np.max(y_true)
    normalized_rmse = np.mean(rmse_per_band) / max_value
    return normalized_rmse

# Function to calculate ERGAS
def ergas(y_true, y_pred, scale):
    bands = y_true.shape[-1]
    ergas_value = 0
    
    for b in range(bands):
        band_true = y_true[:, :, b]
        band_pred = y_pred[:, :, b]
        mean_band_true = np.mean(band_true)
        
        # Calculate RMSE for the band without using a separate function
        mse_band = np.mean((band_true - band_pred) ** 2)  # Mean Squared Error for the band
        rmse_band = np.sqrt(mse_band)  # Root Mean Squared Error for the band
        
        ergas_value += (rmse_band / mean_band_true) ** 2
    
    ergas_value = 100 * (1 / scale) * np.sqrt(ergas_value / bands)
    return ergas_value

# Assuming hybrid_sr_model is trained, and X_test_lr, X_test_hr are defined
predicted_hr_images =  model.predict(X_test_lr)

downscale_factor = 2 # ERGAS downscale factor

# Validate shapes match for test and predictions
if predicted_hr_images.shape != X_test_hr.shape:
    raise ValueError(f"Shape mismatch: predicted_hr_images shape {predicted_hr_images.shape} vs X_test_hr shape {X_test_hr.shape}")

# Calculate metrics per test sample
psnr_values, ssim_values, cc_values, sam_values, ergas_values, rmse_values = [], [], [], [], [], []

for i in range(len(X_test_hr)):
    psnr_values.append(psnr(X_test_hr[i], predicted_hr_images[i]))
    ssim_values.append(ssim_value(X_test_hr[i], predicted_hr_images[i]))
    cc_values.append(correlation_coefficient(X_test_hr[i], predicted_hr_images[i]))
    sam_values.append(sam(X_test_hr[i], predicted_hr_images[i]))
    ergas_values.append(ergas(X_test_hr[i], predicted_hr_images[i], downscale_factor))
    rmse_values.append(rmse_bandwise(X_test_hr[i], predicted_hr_images[i]))

# Average metrics
average_psnr = np.mean(psnr_values)
average_ssim = np.mean(ssim_values)
average_cc = np.mean(cc_values)
average_sam = np.mean(sam_values)
average_ergas = np.mean(ergas_values)
average_rmse = np.mean(rmse_values)

# Print the evaluation metrics
print("Average PSNR on the test set:", average_psnr)
print("Average SSIM on the test set:", average_ssim)
print("Average SAM on the test set (in degrees):", average_sam)
print("Average Correlation Coefficient on the test set:", average_cc)
print("Average ERGAS on the test set:", average_ergas)
print("Average RMSE:", average_rmse)  # Indicate RMSE is normalized
# Out:
# 2025-05-09 16:38:08.504403: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step
# Average PSNR on the test set: 36.570571064949036
# Average SSIM on the test set: 0.95703936
# Average SAM on the test set (in degrees): 3.737526898268344
# Average Correlation Coefficient on the test set: 0.9825941118115523
# Average ERGAS on the test set: 5.827314882495954
# Average RMSE: 0.015009965
